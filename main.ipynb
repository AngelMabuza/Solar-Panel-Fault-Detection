# %%
from utils import Helpers as hp

# %% [markdown]
# ### Check and download data under the 'Data' folder.
# * This Step Creates a 'Data' Folder and dynamically downloads the data from [Zenodo](https://zenodo.org/api/records/5171712)

# %%
hp.download_dataset()
# Out:
# Extracting existing ZIP: PV03.zip
# Corrupted ZIP skipped: PV03.zip
# All required data present.
